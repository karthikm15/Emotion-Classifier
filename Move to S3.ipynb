# %%
import boto3
import os

# %%
s3 = boto3.resource('s3')

# %%
# !aws s3 cp "output" s3://"image-classification-12" --grants read=uri=http://acs.amazonaws.com/groups/global/AllUsers --recursive
# Out:
# upload: output/anger/Alicia_Hollowell_0001.jpg to s3://image-classification-12/anger/Alicia_Hollowell_0001.jpg
# upload: output/anger/Angelina_Jolie_0005.jpg to s3://image-classification-12/anger/Angelina_Jolie_0005.jpg
# upload: output/anger/Alejandro_Toledo_0004.jpg to s3://image-classification-12/anger/Alejandro_Toledo_0004.jpg
# upload: output/anger/Arnold_Schwarzenegger_0023.jpg to s3://image-classification-12/anger/Arnold_Schwarzenegger_0023.jpg
# upload: output/anger/Atal_Bihari_Vajpayee_0010.jpg to s3://image-classification-12/anger/Atal_Bihari_Vajpayee_0010.jpg
# upload: output/anger/Ben_Braun_0001.jpg to s3://image-classification-12/anger/Ben_Braun_0001.jpg
# upload: output/anger/Alvaro_Noboa_0002.jpg to s3://image-classification-12/anger/Alvaro_Noboa_0002.jpg
# upload: output/anger/Billy_Donovan_0001.jpg to s3://image-classification-12/anger/Billy_Donovan_0001.jpg
# ...
